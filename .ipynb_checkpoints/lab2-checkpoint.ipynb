# %% [markdown]
# # Лабораторная работа № 2

# %% [markdown]
# На сетке узлов $\overline{w_{h\tau}}$ найти численное решение смешанной задачи для одномерного уравнения
# теплопроводности с использованием:
# - явной разностной схемы с $\tau = h = 0.1$ и $h = 0.1, \tau = \frac{h^2}{2}$;
# - чисто неявной разностной схемы с $\tau = h = 0.1$;
# - разностной схемы Кранка-Николсон с $\tau = h = 0.1$.
#
# Выписать соответствующие разностные схемы, указать их порядок аппроксимации, указать,
# являются ли схемы абсолютно устойчивыми по начальным данным. Найти $\max_{i, j}|y_i^j - u(x_i, t_j)|$ .
# Построить графики, демонстрирующие устойчивое и неустойчивое поведение явной разностной
# схемы.
# Задача:
# $\begin{cases}
# \frac{\partial u}{\partial t} = \frac{\partial^2 u}{\partial x^2} + 3 e^{-t}cos(2x) & 0 < x < 1, 0 < t \leq 0.5,\\
# u(x, 0) = cos(2x) & 0 \leq x \leq 1,\\
# u(0, t) = e^{-t} & 0 \leq t \leq 0.5,\\
# u(1, t) = e^{-t}cos(2) & 0 \leq t \leq 0.5.\\
# \end{cases}$
# Точное решение:
# $u(x, t) = e^{-t}cos(2x)$

# %% [markdown]
# Выпишем разностные схемы для каждого пункта:
# $\sigma = 0, \tau = h = 0.1 \lor h = 0.1, \tau = 0.005$:
# $\begin{cases}
# y_t = y_{\overline{x}x} + 3 e^{-t}cos(2x) & (x, t) \in w_{h\tau},\\
# y(x, 0) = cos(2x) & x \in w_h,\\
# y(0, t) = e^{-t} &  t \in w_{\tau},\\
# y(1,t) = e^{-t}cos(2) & t \in w_{\tau}.\\
# \end{cases}$
# В индексной форме:
# $\begin{cases}
# \frac{y_i^{j + 1} - y_i^j}{\tau} = \frac{y_{i + 1}^j - 2y_i^j + y_{i - 1}^j}{h^2} + \varphi_i^j & i \in \overline{1, N_1}, j \in \overline{1, N_2 - 1},\\
# y_i^0 = cos(2x_i) & i \in \overline{1, N_1},\\
# y_0^{j+1} = e^{-t_{j+1}} &  j \in \overline{0, N_2 - 1},\\
# y_{N_1}^{j+1} = e^{-t_{j+1}}cos(2) & j \in \overline{0, N_2 - 1}.\\
# \end{cases}$
#
# $\sigma = 1, \tau = h = 0.1$:
# $\begin{cases}
# y_t = \widehat{y_{\overline{x}x}} + 3 e^{-t}cos(2x) & (x, t) \in w_{h\tau},\\
# y(x, 0) = cos(2x) & x \in w_h,\\
# y(0, t) = e^{-t} &  t \in w_{\tau},\\
# y(1,t) = e^{-t}cos(2) & t \in w_{\tau}.\\
# \end{cases}$
# В индексной форме:
# $\begin{cases}
# \frac{y_i^{j + 1} - y_i^j}{\tau} = \frac{y_{i + 1}^{j+1} - 2y_i^{j+1} + y_{i - 1}^{j+1}}{h^2} + \varphi_i^j & i \in \overline{1, N_1}, j \in \overline{0, N_2 - 1},\\
# y_i^0 = cos(2x_i) & i \in \overline{1, N_1},\\
# y_0^{j+1} = e^{-t_{j+1}} & j \in \overline{0, N_2 - 1},\\
# y_{N_1}^{j+1} = e^{-t_{j+1}}cos(2) & j \in \overline{0, N_2 - 1}.\\
# \end{cases}$
#
# $\sigma = \frac{1}{2}, \tau = h = 0.1$:
# $\begin{cases}
# y_t = \frac{1}{2}(y_{\overline{x}x}+\widehat{y_{\overline{x}x}}) + 3 e^{-t-\frac{\tau}{2}}cos(2x) & (x, t) \in w_{h\tau},\\
# y(x, 0) = cos(2x) & x \in w_h,\\
# y(0, t) = e^{-t} &  t \in w_{\tau},\\
# y(1,t) = e^{-t}cos(2) & t \in w_{\tau}.\\
# \end{cases}$
# В индексной форме:
# $\begin{cases}
# \frac{y_i^{j + 1} - y_i^j}{\tau} = \frac{1}{2}\frac{y_{i + 1}^j - 2y_i^j + y_{i - 1}^j}{h^2} + \frac{1}{2}\frac{y_{i + 1}^{j+1} - 2y_i^j + y_{i - 1}^{j+1}}{h^2} + \varphi_i^{j+\frac{1}{2}} & i \in \overline{1, N_1}, j \in \overline{0, N_2 - 1},\\
# y_i^0 = cos(2x_i) & i \in \overline{1, N_1},\\
# y_0^{j+1} = e^{-t_{j+1}} &  j \in \overline{0, N_2 - 1},\\
# y_{N_1}^{j+1} = e^{-t_{j+1}}cos(2) & j \in \overline{0, N_2 - 1}.\\
# \end{cases}$

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def u(x, t):
    return np.exp(-t) * np.cos(2 * x) 

def u0(x):
    return np.cos(2*x)

def mu0(t):
    return np.exp(-t)

def muN2(t):
    return np.exp(-t) * np.cos(2)

def f(x, t):
    return 3 * np.exp(-t) * np.cos(2 * x)

# %% [markdown]
# $\sigma = 0, \tau = h = 0.1$:

# %%
h = 0.1
tau = h
N1 = int(1 / h)
N2 = int(0.5 / tau)

# %%
t = []
for i in range(N2 + 1):
    t.append(i * tau)

x = []
for i in range(N1 + 1):
    x.append(i * h)

# %%
u_0 = []
for x_ in x:
    u_0.append(u0(x_))
    
mu_0 = []
for t_ in t:
    mu_0.append(mu0(t_))
    
mu_N2 = []
for t_ in t:
    mu_N2.append(muN2(t_))
    
phi = []
for j in range(N2 + 1):
    phi.append([])
    for i in range(N1 + 1):
        phi[j].append(f(x[i], t[j]))

# %%
y = []
for j in range(N2 + 1):
    y.append([])
    for i in range(N1 + 1):
        if j == 0:
            y[j] = u_0
        elif j != 0 and 0 < i < N1:
            y[j].append(y[j - 1][i] * tau/(h ** 2) * (y[j - 1][i + 1] - 2 * y[j - 1][i] + y[j - 1][i + 1]) + tau * phi[j - 1][i])
        elif j != 0 and i == 0:
            y[j].append(mu0(t[j]))
        elif j != 0 and i == N1:
            y[j].append(muN2(t[j]))

# %%
uline = []
for xl in x:
    uline.append(u(xl, t[0]))


plt.plot(x, uline, label='точное решение', linewidth=4)
plt.plot(x, y[0], label='приближённое решение')
plt.show()

# %%
uline = []
for tl in t:
    uline.append(u(x[0], tl))


plt.plot(t, np.transpose(y)[0], linewidth=4)
plt.plot(t, uline)
plt.show()

# %%
uline = []
for xl in x:
    uline.append(u(xl, t[4]))


plt.plot(x, uline, label='точное решение', linewidth=4)
plt.plot(x, y[4], label='приближённое решение')
plt.show()

# %%
uline = []
for tl in t:
    uline.append(u(x[4], tl))


plt.plot(t, np.transpose(y)[4], linewidth=4)
plt.plot(t, uline)
plt.show()

# %% [markdown]
# Невязка:

# %%
diff = []
for j in range(N2 + 1):
    diff.append([])
    for i in range(N1 + 1):
        diff[j].append(abs(y[j][i] - u(x[i], t[j])))

max_j = []
for d in diff:
    max_j.append(max(d))
    
print(max(max_j))
# Out:
# 1.6368708861082812e+19

# %% [markdown]
# $\sigma = 0, h = 0.1, \tau = 0.005$:

# %%
tau = h ** 2 / 2
N2 = int(0.5 / tau)

# %%
t = []
for i in range(N2 + 1):
    t.append(i * tau)

# %%
mu_0 = []
for t_ in t:
    mu_0.append(mu0(t_))
    
mu_N2 = []
for t_ in t:
    mu_N2.append(muN2(t_))
    
phi = []
for j in range(N2 + 1):
    phi.append([])
    for i in range(N1 + 1):
        phi[j].append(f(x[i], t[j]))

# %%
y = []
for j in range(N2 + 1):
    y.append([])
    for i in range(N1 + 1):
        if j == 0:
            y[j] = u_0
        elif j != 0 and 0 < i < N1:
            y[j].append(y[j - 1][i] * tau/(h ** 2) * (y[j - 1][i + 1] - 2 * y[j - 1][i] + y[j - 1][i + 1]) + tau * phi[j - 1][i])
        elif j != 0 and i == 0:
            y[j].append(mu0(t[j]))
        elif j != 0 and i == N1:
            y[j].append(muN2(t[j]))

# %%
uline = []
for xl in x:
    uline.append(u(xl, t[0]))


plt.plot(x, uline, label='точное решение', linewidth=4)
plt.plot(x, y[0], label='приближённое решение')
plt.show()

# %%
uline = []
for tl in t:
    uline.append(u(x[0], tl))


plt.plot(t, np.transpose(y)[0], linewidth=4)
plt.plot(t, uline)
plt.show()

# %%
uline = []
for xl in x:
    uline.append(u(xl, t[4]))


plt.plot(x, uline, label='точное решение', linewidth=4)
plt.plot(x, y[4], label='приближённое решение')
plt.show()

# %%
uline = []
for tl in t:
    uline.append(u(x[4], tl))


plt.plot(t, np.transpose(y)[4], linewidth=4)
plt.plot(t, uline)
plt.show()

# %% [markdown]
# Невязка:

# %%
diff = []
for j in range(N2 + 1):
    diff.append([])
    for i in range(N1 + 1):
        diff[j].append(abs(y[j][i] - u(x[i], t[j])))

max_j = []
for d in diff:
    max_j.append(max(d))
    
print(max(max_j))
# Out:
# 1.0183068773500656

# %% [markdown]
# $\sigma = 1, \tau = h = 0.1$:

# %%
h = 0.1
tau = h
N1 = int(1 / h)
N2 = int(0.5 / tau)

# %%
t = []
for i in range(N2 + 1):
    t.append(i * tau)

x = []
for i in range(N1 + 1):
    x.append(i * h)

# %%
u_0 = []
for x_ in x:
    u_0.append(u0(x_))
    
mu_0 = []
for t_ in t:
    mu_0.append(mu0(t_))
    
mu_N2 = []
for t_ in t:
    mu_N2.append(muN2(t_))
    
phi = []
for j in range(N2 + 1):
    phi.append([])
    for i in range(N1 + 1):
        phi[j].append(f(x[i], t[j]))

# %%
A = []
A = np.zeros((N1 + 1, N1 + 1))
for i in range(N1 + 1):
#     A.append([])
    for j in range(N1 + 1):
        if i == 0 and j == 0:
            A[i][j] = 1
        elif i == 0 and j != 0:
            A[i][j] = 0
        elif i == N1:
            if j == i:
                A[i][j] = 1
            else:
                A[i][j] = 0
        elif 0 < i < N1:
            if j == i:
                A[i][j] = (-1/h**2 - 1/tau)
            elif j == i - 1 or j == i + 1:
                A[i][j] = (1/(h**2))

                
y0 = []
for x_ in x:
    y0.append(u0(x_))

y0 = np.array(y0)    
        
y = []
y.append(y0)
# for i in range(N1 + 1):
#     if i == 0:
#         yj.append(yj0)
#     else:
#         yj.append([])
        
for j in range(1, N2 + 1):
    b = []
    for i in range(N1 + 1):
        if i == 0:
            b.append(mu0(t[j]))
        elif i == N1:
            b.append(muN2(t[j]))
        else:
            b.append(-1/tau * y[j - 1][i] + f(x[i], t[j - 1]))
            
            
    y.append(np.dot(np.linalg.inv(A), b))

# %%
y
# Out:
# [array([ 1.        ,  0.98006658,  0.92106099,  0.82533561,  0.69670671,
#          0.54030231,  0.36235775,  0.16996714, -0.02919952, -0.22720209,
#         -0.41614684]),
#  array([ 0.90483742, -0.42890653, -1.44523927, -1.22533093,  0.03960175,
#          1.22012339,  1.26471281,  0.14569566, -1.11634528, -1.37163151,
#         -0.37654523]),
#  array([ 0.81873075,  1.25210255,  0.62807674, -0.3916919 , -0.9140009 ,
#         -0.59875707,  0.14802235,  0.64494663,  0.55146315,  0.07250474,
#         -0.34071221]),
#  array([ 0.74081822, -0.7873386 , -1.70802861, -1.13167752,  0.52262436,
#          1.81507686,  1.54710676, -0.11916146, -1.73850431, -1.84905679,
#         -0.30828916]),
#  array([ 0.67032005,  1.82807477,  1.44107759, -0.05161639, -1.36634516,
#         -1.48814173, -0.44011046,  0.85736279,  1.39890311,  0.85463212,
#         -0.27895157]),
#  array([ 0.60653066, -1.69869783, -2.638197  , -1.32890446,  1.19816091,
#          2.79752647,  2.03879765, -0.50355114, -2.67502221, -2.57945079,
#         -0.25240582])]

# %%
uline = []
for xl in x:
    uline.append(u(xl, t[0]))


plt.plot(x, uline, label='точное решение', linewidth=4)
plt.plot(x, y[0], label='приближённое решение')
plt.show()

# %%
uline = []
for tl in t:
    uline.append(u(x[0], tl))


plt.plot(t, np.transpose(y)[0], linewidth=4)
plt.plot(t, uline)
plt.show()

# %%
uline = []
for xl in x:
    uline.append(u(xl, t[4]))


plt.plot(x, uline, label='точное решение', linewidth=4)
plt.plot(x, y[4], label='приближённое решение')
plt.show()

# %%
uline = []
for tl in t:
    uline.append(u(x[4], tl))


plt.plot(t, np.transpose(y)[4], linewidth=4)
plt.plot(t, uline)
plt.show()

# %% [markdown]
# Невязка:

# %%
diff = []
for j in range(N2 + 1):
    diff.append([])
    for i in range(N1 + 1):
        diff[j].append(abs(y[j][i] - u(x[i], t[j])))

max_j = []
for d in diff:
    max_j.append(max(d))

print(max(max_j))
# Out:
# 3.1968487365945744

# %% [markdown]
# $\sigma = \frac{1}{2}, \tau = h = 0.1$:

# %%
h = 0.1
tau = h
N1 = int(1 / h)
N2 = int(0.5 / tau)

t = []
for i in range(N2 + 1):
    t.append(i * tau)

x = []
for i in range(N1 + 1):
    x.append(i * h)

u_0 = []
for x_ in x:
    u_0.append(u0(x_))
    
mu_0 = []
for t_ in t:
    mu_0.append(mu0(t_))
    
mu_N2 = []
for t_ in t:
    mu_N2.append(muN2(t_))
    
phi = []
for j in range(N2 + 1):
    phi.append([])
    for i in range(N1 + 1):
        phi[j].append(f(x[i], t[j] + tau/2))

# %%
A = []
A = np.zeros((N1 + 1, N1 + 1))
for i in range(N1 + 1):
    for j in range(N1 + 1):
        if i == 0 and j == 0:
            A[i][j] = 1
        elif i == 0 and j != 0:
            A[i][j] = 0
        elif i == N1:
            if j == i:
                A[i][j] = 1
            else:
                A[i][j] = 0
        elif 0 < i < N1:
            if j == i:
                A[i][j] = (-1/h**2 - 1/tau)
            elif j == i - 1 or j == i + 1:
                A[i][j] = (1/(2 * h**2))

                
y0 = []
for x_ in x:
    y0.append(u0(x_))

y0 = np.array(y0)    
        
y = []
y.append(y0)
        
for j in range(1, N2 + 1):
    b = []
    for i in range(N1 + 1):
        if i == 0:
            b.append(mu0(t[j]))
        elif i == N1:
            b.append(muN2(t[j]))
        else:
            b.append(-1/tau * y[j - 1][i] - 1/(2 * h ** 2) * (y[j - 1][i - 1] - 2 * y[j - 1][i] + y[j - 1][i + 1]) - f(x[i], t[j - 1] + tau/2))
            
            
    y.append(np.dot(np.linalg.inv(A), b))

# %%
y
# Out:
# [array([ 1.        ,  0.98006658,  0.92106099,  0.82533561,  0.69670671,
#          0.54030231,  0.36235775,  0.16996714, -0.02919952, -0.22720209,
#         -0.41614684]),
#  array([ 0.90483742,  0.88703887,  0.83377086,  0.7471962 ,  0.63079216,
#          0.48921704,  0.32812793,  0.15395779, -0.02633883, -0.20556087,
#         -0.37654523]),
#  array([ 0.81873075,  0.80260159,  0.75444137,  0.67615603,  0.57086965,
#          0.44279019,  0.29703681,  0.13943318, -0.02372642, -0.18593018,
#         -0.34071221]),
#  array([ 0.74081822,  0.72627097,  0.68269206,  0.61184903,  0.51657932,
#          0.40068887,  0.26880481,  0.12619233, -0.02145458, -0.16823853,
#         -0.30828916]),
#  array([ 0.67032005,  0.65713908,  0.61772492,  0.55363782,  0.4674389 ,
#          0.36257498,  0.24323721,  0.11419339, -0.01940221, -0.15221571,
#         -0.27895157]),
#  array([ 0.60653066,  0.5946215 ,  0.55894694,  0.50095206,  0.42295641,
#          0.32807488,  0.22009645,  0.10333296, -0.01755339, -0.13773497,
#         -0.25240582])]

# %%
uline = []
for xl in x:
    uline.append(u(xl, t[0]))


plt.plot(x, uline, label='точное решение', linewidth=4)
plt.plot(x, y[0], label='приближённое решение')
plt.show()

# %%
uline = []
for tl in t:
    uline.append(u(x[0], tl))


plt.plot(t, np.transpose(y)[0], linewidth=4)
plt.plot(t, uline)
plt.show()

# %%
uline = []
for xl in x:
    uline.append(u(xl, t[4]))


plt.plot(x, uline, label='точное решение', linewidth=4)
plt.plot(x, y[4], label='приближённое решение')
plt.show()

# %%
uline = []
for tl in t:
    uline.append(u(x[4], tl))


plt.plot(t, np.transpose(y)[4], linewidth=4)
plt.plot(t, uline)
plt.show()

# %% [markdown]
# Невязка:

# %%
diff = []
for j in range(N2 + 1):
    diff.append([])
    for i in range(N1 + 1):
        diff[j].append(abs(y[j][i] - u(x[i], t[j])))

max_j = []
for d in diff:
    max_j.append(max(d))
    
print(max(max_j))
# Out:
# 0.00045444248385351216
